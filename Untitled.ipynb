# %% [markdown]
# ## Problem Statement
# - To build a classification methodology to determine whether a person defaults the credit card payment for the next month.
#
#
# ## Features:
#
# 1.	LIMIT_BAL: continuous.Credit Limit of the person.
# 2.	SEX: Categorical: 1 = male; 2 = female
# 3.	EDUCATION: Categorical: 1 = graduate school; 2 = university; 3 = high school; 4 = others
# 4.	MARRIAGE: 1 = married; 2 = single; 3 = others
# 5.	AGE-num: continuous.
# 6.	PAY_0 to PAY_6: History of past payment. We tracked the past monthly payment records (from April to September, 2005)
# 7.	BILL_AMT1 to BILL_AMT6: Amount of bill statements.
# 8.	PAY_AMT1 to PAY_AMT6: Amount of previous payments.
# #### **Target Label: (Whether a person shall default in the credit card payment or not.)**
# 9.	default payment next month:  Yes = 1, No = 0.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
import os
os.chdir(r"C:\Users\Abhishek\Desktop\Data Sets\Project")
# Out:
# In F:\Anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In F:\Anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In F:\Anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In F:\Anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In F:\Anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# ...

# %%
data = pd.read_excel("CreditCardDefaulters.xls")
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# # 1. EDA

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data.shape
# Out:
# (30000, 24)

# %%
data.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### Data is Highly Imbalanced

# %%
sns.countplot(data['default payment next month'])

print("Records for Class 0 :{} \nRecords for Class 1 :{}".format(data['default payment next month'].value_counts()[0],data['default payment next month'].value_counts()[1]))
# Out:
# Records for Class 0 :23364
# Records for Class 1 :6636

# %%
y_count = data['default payment next month'].value_counts()

print("Class 0 : {}%".format((y_count[0] / data.shape[0])*100))
print("Class 1 : {}%".format((y_count[1] / data.shape[0])*100))
# Out:
# Class 0 : 77.88000000000001%
# Class 1 : 22.12%

# %% [markdown]
# #### Correlation

# %%
correlation = data.corr()

plt.figure(figsize=(12,8))
sns.heatmap(correlation , cmap = 'CMRmap' )
# Out:
# <AxesSubplot:>

# %%
correlation.sort_values(by=['default payment next month'] , ascending=False)['default payment next month']
# Out:
# default payment next month    1.000000
# PAY_0                         0.324794
# PAY_2                         0.263551
# PAY_3                         0.235253
# PAY_4                         0.216614
# PAY_5                         0.204149
# PAY_6                         0.186866
# EDUCATION                     0.028006
# AGE                           0.013890
# BILL_AMT6                    -0.005372
# BILL_AMT5                    -0.006760
# BILL_AMT4                    -0.010156
# BILL_AMT3                    -0.014076
# BILL_AMT2                    -0.014193
# BILL_AMT1                    -0.019644
# MARRIAGE                     -0.024339
# SEX                          -0.039961
# PAY_AMT6                     -0.053183
# PAY_AMT5                     -0.055124
# PAY_AMT3                     -0.056250
# PAY_AMT4                     -0.056827
# PAY_AMT2                     -0.058579
# PAY_AMT1                     -0.072929
# LIMIT_BAL                    -0.153520
# ...

# %% [markdown]
# ## VIF
#
# - Age ,  Bill Amounts have a high score. We can try and delete some of these to  reduce the Multicollinearity.

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

X = data.iloc[:,:-1]
calc_vif(X)
# Out:
#     variables        VIF
# 0   LIMIT_BAL   4.037479
# 1         SEX   9.092210
# 2   EDUCATION   6.731119
# 3    MARRIAGE   6.265388
# 4         AGE  10.857679
# 5       PAY_0   1.918276
# 6       PAY_2   3.211217
# 7       PAY_3   3.727427
# 8       PAY_4   4.440120
# 9       PAY_5   4.985856
# 10      PAY_6   3.463800
# 11  BILL_AMT1  20.823400
# 12  BILL_AMT2  38.214225
# 13  BILL_AMT3  31.783029
# 14  BILL_AMT4  29.548135
# 15  BILL_AMT5  35.986369
# 16  BILL_AMT6  21.426076
# 17   PAY_AMT1   1.907500
# 18   PAY_AMT2   2.384860
# 19   PAY_AMT3   1.911689
# 20   PAY_AMT4   1.805048
# 21   PAY_AMT5   1.854229
# 22   PAY_AMT6   1.270665

# %% [markdown]
# ---

# %%
data.groupby(["default payment next month"]).median()
# Out:
#                             LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  \
# default payment next month
# 0                            150000.0  2.0        2.0       2.0  34.0    0.0
# 1                             90000.0  2.0        2.0       2.0  34.0    1.0
#
#                             PAY_2  PAY_3  PAY_4  PAY_5  ...  BILL_AMT3  \
# default payment next month                              ...
# 0                             0.0    0.0    0.0    0.0  ...    20202.5
# 1                             0.0    0.0    0.0    0.0  ...    19834.5
#
#                             BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# default payment next month
# 0                             19000.0    17998.0    16679.0    2459.5
# 1                             19119.5    18478.5    18028.5    1636.0
#
#                             PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# default payment next month
# 0                             2247.5    2000.0    1734.0    1765.0    1706.0
# ...

# %%
data.groupby(["default payment next month"]).mean()
# Out:
#                                 LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# default payment next month
# 0                           178099.726074  1.614150   1.841337  1.558637
# 1                           130109.656420  1.567058   1.894665  1.528029
#
#                                   AGE     PAY_0     PAY_2     PAY_3     PAY_4  \
# default payment next month
# 0                           35.417266 -0.211222 -0.301917 -0.316256 -0.355633
# 1                           35.725738  0.668174  0.458258  0.362116  0.254521
#
#                                PAY_5  ...     BILL_AMT3     BILL_AMT4  \
# default payment next month            ...
# 0                          -0.389488  ...  47533.365605  43611.165254
# 1                           0.167872  ...  45181.598855  42036.950573
#
#                                BILL_AMT5     BILL_AMT6     PAY_AMT1  \
# default payment next month
# 0                           40530.445343  39042.268704  6307.337357
# ...

# %% [markdown]
# #### Mean  LIMIT_BAL for 0 is Greater than for 1

# %%
plt.figure(figsize=(8,6))
sns.violinplot(data['default payment next month'] , data['LIMIT_BAL'])
plt.xticks(ticks=[0,1],labels=["Not Default" , "Default"])
plt.plot()
# Out:
# []

# %%
sns.countplot(data['default payment next month'] , hue=data["SEX"])
plt.xticks(ticks=[0,1],labels=["Not Default" , "Default"])
plt.plot()
# Out:
# []
